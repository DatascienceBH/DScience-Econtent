# %%
set.seed(20)
irisCluster <- kmeans(iris[, 1:4], 3)

# %%
table(irisCluster$cluster, iris$Species)
# Out:
#
#     setosa versicolor virginica
#   1      0          2        36
#   2      0         48        14
#   3     50          0         0

# %%
install.packages("GGally")
library(GGally)
# Out:
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”Warning message:
# “package ‘GGally’ is not available (for R version 3.5.1)”

# %%
irisCluster$cluster <- as.factor(irisCluster$cluster)
ggplot(iris, aes(Petal.Length, Petal.Width, color = irisCluster$cluster)) + geom_point()
# Out:
# plot without title

# %%
getwd()
# Out:
# [1] "/Users/medamin/Projets/DataScience"

# %%
df<- read.csv("test.csv")

# %%
head(df)
# Out:
#   X Secceed_Count Failed_Count Max_Consecutive_Failed_Count Average_Ping_Time
# 1 1 9             0            NA                            2
# 2 2 0             9             9                           NA
# 3 3 9             0            NA                            3
# 4 4 0             9             9                           NA
# 5 5 9             0            NA                            2
# 6 6 9             0            NA                            1
#   Difference Failed_State Month Day Last_Ping_TTL
# 1 NA         0            6     27  248
# 2  0         1            6     27   NA
# 3 NA         0            6     27  248
# 4  0         1            6     27   NA
# 5 NA         0            6     27  248
# 6 NA         0            6     27   57

# %%
names(df)
# Out:
#  [1] "X"                            "Secceed_Count"
#  [3] "Failed_Count"                 "Max_Consecutive_Failed_Count"
#  [5] "Average_Ping_Time"            "Difference"
#  [7] "Failed_State"                 "Month"
#  [9] "Day"                          "Last_Ping_TTL"

# %%
table(is.na(df$Max_Consecutive_Failed_Count))
# Out:
# FALSE
#   994

# %%
mean(df$Max_Consecutive_Failed_Count, na.rm=T)
# Out:
# [1] 6.37931

# %%
df$Max_Consecutive_Failed_Count[is.na(df$Max_Consecutive_Failed_Count)]<-mean(df$Max_Consecutive_Failed_Count, na.rm=T)

# %%
table(is.na(df$Average_Ping_Time))
# Out:
# FALSE
#   994

# %%
df$Average_Ping_Time[is.na(df$Average_Ping_Time)]<-mean(df$Average_Ping_Time, na.rm=T)

# %%
table(is.na(df$Last_Ping_TTL))
# Out:
# FALSE
#   994

# %%
df$Last_Ping_TTL[is.na(df$Last_Ping_TTL)]<-mean(df$Last_Ping_TTL, na.rm=T)

# %%
y<- c(4,5,6,NA)
z<- c(NA, 7,8,9)
dt<-data.frame(y=y, z=z)
dt
# Out:
#   y  z
# 1  4 NA
# 2  5  7
# 3  6  8
# 4 NA  9

# %%
is.na(dt)
# Out:
#      y     z
# [1,] FALSE  TRUE
# [2,] FALSE FALSE
# [3,] FALSE FALSE
# [4,]  TRUE FALSE

# %%
 mean(dt$y, na.rm=T)
# Out:
# [1] 5

# %%
dt[is.na(dt$y),]<-mean(dt$y, na.rm=T)

# %%
dt
# Out:
#   y z
# 1 4 NA
# 2 5  7
# 3 6  8
# 4 5  5

# %%
dt[is.na(dt)]<-mean(dt[!na.rm])
# Out:
# Error in `[.data.frame`(dt, !na.rm): object 'na.rm' not found
# Traceback:
#
# 1. mean(dt[!na.rm])
# 2. dt[!na.rm]
# 3. `[.data.frame`(dt, !na.rm)

# %%
?write

# %%
load("mydata.RData")
write.csv(mydata, "mydata.csv")

# %%
head(mydata)    4, 5,6,7,8,9,11,13
# Out:
#   IP_Address   Description
# 1 10.100.10.12       الخليج العربي الإعدادية الابتدائية للبنات
# 2 10.100.10.12       الخليج العربي الإعدادية الابتدائية للبنات
# 3 10.100.10.3        الخليج العربي الإعدادية الابتدائية للبنات
# 4 10.100.10.3        الخليج العربي الإعدادية الابتدائية للبنات
# 5 10.100.20.3        الخليج العربي الإعدادية الابتدائية للبنات
# 6 10.100.20.3        الخليج العربي الإعدادية الابتدائية للبنات
#   date                Secceed_Count Failed_Count Max_Consecutive_Failed_Count
# 1 2019-06-26 14:35:00  2            7            6
# 2 2019-06-27 14:35:00 18            0            0
# 3 2019-06-26 14:35:00  0            9            9
# 4 2019-06-27 14:35:00 18            0            0
# 5 2019-06-26 14:35:00  3            6            6
# 6 2019-06-27 14:35:00 18            0            0
#   Failed_Percentage Last_Ping_TTL Average_Ping_Time Difference Failed_State
# 1  77.77778           0           1                 1          0
# ...

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:GGally’:
#
#     nasa
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mydata %>%
    select( Description, Day)
group_by(Failed_State)
summarise(  count=n())
# Out:
#     Description                                       Day
# 1         الخليج العربي الإعدادية الابتدائية للبنات   26
# 2         الخليج العربي الإعدادية الابتدائية للبنات   27
# 3         الخليج العربي الإعدادية الابتدائية للبنات   26
# 4         الخليج العربي الإعدادية الابتدائية للبنات   27
# 5         الخليج العربي الإعدادية الابتدائية للبنات   26
# 6         الخليج العربي الإعدادية الابتدائية للبنات   27
# 7         Riffa Public Library                        26
# 8         Riffa Public Library                        27
# 9         GiftedInstitute - مركز التميز               26
# 10        GiftedInstitute - مركز التميز               27
# 11        معهد الشيخ خليفة بن سلمان للتكنولوجيا       26
# 12        معهد الشيخ خليفة بن سلمان للتكنولوجيا       27
# 13        معهد الشيخ خليفة بن سلمان للتكنولوجيا       26
# 14        معهد الشيخ خليفة بن سلمان للتكنولوجيا       27
# 15        معهد الشيخ خليفة بن سلمان للتكنولوجيا       26
# ...

# %%
mydata$Max_Consecutive_Failed_Count[is.na(mydata$Max_Consecutive_Failed_Count)]<-mean(mydata$Max_Consecutive_Failed_Count, na.rm=T)

# %%
mydata$Average_Ping_Time[is.na(mydata$Average_Ping_Time)]<-mean(mydata$Average_Ping_Time, na.rm=T)

# %%
mydata$Last_Ping_TTL[is.na(mydata$Last_Ping_TTL)]<-mean(mydata$Last_Ping_TTL, na.rm=T)

# %%
table(is.na(mydata$Max_Consecutive_Failed_Count))
# Out:
# FALSE
#   994

# %%
names(mydata)
# Out:
#  [1] "IP_Address"                   "Description"
#  [3] "date"                         "Secceed_Count"
#  [5] "Failed_Count"                 "Max_Consecutive_Failed_Count"
#  [7] "Failed_Percentage"            "Last_Ping_TTL"
#  [9] "Average_Ping_Time"            "Difference"
# [11] "Failed_State"                 "Month"
# [13] "Day"

# %%
typeof(mydata$Last_Ping_TTL)
# Out:
# [1] "integer"

# %%
install.packages("GGally")
library(GGally)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: ggplot2

# %%
set.seed(20)
deviceCluster <- kmeans(mydata[, 4:7],3)
table(deviceCluster$cluster, mydata$Failed_State)
# Out:
#
#       0   1   2
#   1   0   0 823
#   2   9  29  19
#   3 114   0   0

# %%
deviceCluster$cluster<- as.factor(deviceCluster$cluster)

# %%
ggplot(mydata, aes(mydata$Failed_Count, mydata$Failed_Percentage, color = deviceCluster$cluster)) + geom_point()
# Out:
# plot without title

# %%
library(shiny)
runExample("04_mpg")

diamonds[diamonds$price<500]
names("diamonds")
d<- data("diamonds")
head(iris)
head(diamonds)
library(MASS)
data()
# Out:
# Error in library(shiny): there is no package called ‘shiny’
# Traceback:
#
# 1. library(shiny)
# 2. stop(txt, domain = NA)

# %%
install.packages("GGally")
library(GGally)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
set.seed(20)
irisCluster <- kmeans(iris[, 1:4], 3)
table(irisCluster$cluster, iris$Species)
# Out:
#
#     setosa versicolor virginica
#   1      0          2        36
#   2      0         48        14
#   3     50          0         0

# %%
irisCluster$cluster <- as.factor(irisCluster$cluster)
ggplot(iris, aes(Petal.Length, Petal.Width, color = irisCluster$cluster)) + geom_point()
# Out:
# plot without title

# %%
(a<-c(2,3,3))
# Out:
# [1] 2 3 3

# %%
set.seed(1)
x <- c(rnorm(24), 4) 
y <- 1 + x + rnorm(25)
plot(y ~ x)
LinMod1 <- lm(y~x)
abline(LinMod1)
# Out:
# plot without title

# %%
(lev1 <- hatvalues(LinMod1))
which(lev1 > 3*2/25)
# Out:
#          1          2          3          4          5          6          7
# 0.06425510 0.04040509 0.07638832 0.08673693 0.04001842 0.07542652 0.04094422
#          8          9         10         11         12         13         14
# 0.04528953 0.04207196 0.05040253 0.08088850 0.04020713 0.06398403 0.21776307
#         15         16         17         18         19         20         21
# 0.05889214 0.04340957 0.04287080 0.05147741 0.04750067 0.04235731 0.05060307
#         22         23         24         25
# 0.04641015 0.04147356 0.18737564 0.42284832
# 25
# 25

# %%
dotchart(mydata$Failed_State, groups = myGroup)
# Out:
# Error in xy.coords(x, y): 'x' and 'y' lengths differ
# Traceback:
#
# 1. dotchart(mydata$Failed_State, groups = myGroup)
# 2. points(x, y, pch = pch, col = color, bg = bg, cex = pt.cex/cex)
# 3. points.default(x, y, pch = pch, col = color, bg = bg, cex = pt.cex/cex)
# 4. plot.xy(xy.coords(x, y), type = type, ...)
# 5. xy.coords(x, y)
# 6. stop("'x' and 'y' lengths differ")
# plot without title

# %%
names(mydata)
head(mydata)
# Out:
#  [1] "IP_Address"                   "Description"
#  [3] "date"                         "Secceed_Count"
#  [5] "Failed_Count"                 "Max_Consecutive_Failed_Count"
#  [7] "Failed_Percentage"            "Last_Ping_TTL"
#  [9] "Average_Ping_Time"            "Difference"
# [11] "Failed_State"                 "Month"
# [13] "Day"
#   IP_Address   Description
# 1 10.100.10.12       الخليج العربي الإعدادية الابتدائية للبنات
# 2 10.100.10.12       الخليج العربي الإعدادية الابتدائية للبنات
# 3 10.100.10.3        الخليج العربي الإعدادية الابتدائية للبنات
# 4 10.100.10.3        الخليج العربي الإعدادية الابتدائية للبنات
# 5 10.100.20.3        الخليج العربي الإعدادية الابتدائية للبنات
# 6 10.100.20.3        الخليج العربي الإعدادية الابتدائية للبنات
#   date                Secceed_Count Failed_Count Max_Consecutive_Failed_Count
# 1 2019-06-26 14:35:00  2            7            6
# 2 2019-06-27 14:35:00 18            0            0
# 3 2019-06-26 14:35:00  0            9            9
# ...

# %%
ibrary(shiny)


# Data pre-processing ----
# Tweak the "am" variable to have nicer factor labels -- since this
# doesn't rely on any user inputs, we can do this once at startup
# and then use the value throughout the lifetime of the app

mydata$Failed_State <- factor(mydata$Failed_State, labels = c("Low", "Medium", "High"))


# Define UI for miles per gallon app ----
ui <- fluidPage(

  # App title ----
  titlePanel("Device State"),

  # Sidebar layout with input and output definitions ----
  sidebarLayout(

    # Sidebar panel for inputs ----
    sidebarPanel(

      # Input: Selector for variable to plot against mpg ----
      selectInput("variable", "Variable:",
                  c("Day" = "Day",
                    "Failed Sate" = "Failed_Sate"
                 
                 ),

      # Input: Checkbox for whether outliers should be included ----
      checkboxInput("outliers", "Show outliers", TRUE)

    ),

    # Main panel for displaying outputs ----
    mainPanel(

      # Output: Formatted text for caption ----
      h3(textOutput("caption")),

      # Output: Plot of the requested variable against mpg ----
      plotOutput("mpgPlot")

    )
  )
)

# Define server logic to plot various variables against mpg ----
server <- function(input, output) {

  # Compute the formula text ----
  # This is in a reactive expression since it is shared by the
  # output$caption and output$mpgPlot functions
  formulaText <- reactive({
    paste("FailedSate ~", input$variable)
  })

  # Return the formula text for printing as a caption ----
  output$caption <- renderText({
    formulaText()
  })

  # Generate a plot of the requested variable against mpg ----
  # and only exclude outliers if requested
  output$mpgPlot <- renderPlot({
    boxplot(as.formula(formulaText()),
            data = mpgData,
            outline = input$outliers,
            col = "#75AADB", pch = 19)
  })

}

# Create Shiny app ----
shinyApp(ui, server)
# Out:
# Error in parse(text = x, srcfile = src): <text>:50:1: unexpected symbol
# 49: # Define server logic to plot various variables against mpg ----
# 50: server
#     ^
# Traceback:
